# %%
import os
import keras
from keras.applications.inception_v3 import preprocess_input# import inception_v3 as inc_net
from keras.preprocessing import image
from keras.models import load_model
from skimage.io import imread
#from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

print('Notebook run using keras:', keras.__version__)
# Out:
# Using TensorFlow backend.
# Notebook run using keras: 2.1.6

# %%
img_size = 299
path_to_labels = "./sonstiges/mushroom_labels.txt"

def getHighestID(preds):
    id = -1
    max = -1
    for i in range(len(preds)):
        if preds[i][1]>max:
            max = preds[i][1]
            id=i
    return id

def getLabels():
    with open(path_to_labels, 'r') as f:
     myLabels = [line.strip() for line in f]
    return myLabels

def getLabelFromID(id):
    with open(path_to_labels) as fp:
        for i, line in enumerate(fp):
            if i == id:
                return line
    raise Exception('ID is not in file')
    
def decode_prediction(preds):
    label_list = getLabels()    
    decoded_list = list()
    decoded_list.append([])
    for i in range(len(label_list)):
        decoded_list[0].append([label_list[i],preds[0][i]])
    return decoded_list

def getIDFromLabel(label):
    with open(path_to_labels) as fp:
        for i, line in enumerate(fp):
            if label == line.replace('\n',''):
                return i
    raise Exception('Label is not in file')

# %%
def transform_img_fn(path_list):
    out = []
    for img_path in path_list:
        img = image.load_img(img_path, target_size=(img_size, img_size))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        out.append(x)
    return np.vstack(out)

# %%
my_model = load_model('mushrooms_FINAL_299_Epocs12_Steps3371_2018-06-19 14:35:50.515233.h5')
print('Model loaded')
# Out:
# Model loaded

# %%
images = transform_img_fn([os.path.join('data','Corpinus comatus.jpg')])
preds = my_model.predict(images)

# %%
plt.imshow(images[0]/2 +0.5)

preds = decode_prediction(preds)[0]
preds = sorted(preds,key=lambda l:l[1], reverse=True)
for x in preds[:5]:
    print(x)
# Out:
# ['Hygrophorus hypothejus', 0.9998672]
# ['Hygrophorus camarophyllus', 0.000107503365]
# ['Amanita phalloides', 1.2749252e-05]
# ['Gomphidius glutinosus', 9.249881e-06]
# ['Stropharia hornemannii', 1.9672511e-06]

# %%
# %load_ext autoreload
# %autoreload 2
import os,sys
try:
    import lime
except:
    sys.path.append(os.path.join('..', '..')) # add the current directory
    import lime
from lime import lime_image
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
explainer = lime_image.LimeImageExplainer()

# %%
# %%time
# Hide color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
explanation = explainer.explain_instance(images[0], my_model.predict, hide_color=None, num_samples=1000)
# Out:
# CPU times: user 13.3 s, sys: 1.61 s, total: 14.9 s
# Wall time: 14.9 s

# %%
from skimage.segmentation import mark_boundaries
#print(preds.index('Coprinus comatus'))
print(preds)
temp, mask = explanation.get_image_and_mask(71, positive_only=True, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-0cd0c9328b28> in <module>()
#       1 from skimage.segmentation import mark_boundaries
# ----> 2 print(preds.index('Coprinus comatus'))
#       3 temp, mask = explanation.get_image_and_mask(71, positive_only=True, hide_rest=True)
#       4 plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
#       5
#
# ValueError: 'Coprinus comatus' is not in list
